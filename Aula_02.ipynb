# %% [markdown]
# <a href="https://colab.research.google.com/github/eliaszapata2018/Codigos_Python/blob/main/Aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 02 - Operações Matemáticas

# %% [markdown]
# ![Screen Shot 2022-07-18 at 20.52.10.png](data:image/png;base64,...)

# %% [markdown]
# ## Soma

# %%
10+5
# Out:
# 15

# %% [markdown]
# ## Subtração

# %%
17-2
# Out:
# 15

# %% [markdown]
# ## Multiplicação

# %%
8*5
# Out:
# 40

# %% [markdown]
# ## Divisão

# %%
64/8 # cuidado para não confundir com \
# Out:
# 8.0

# %% [markdown]
# ## Potência

# %%
2**4 # 2 elevado a 4
# Out:
# 16

# %%
3**3
# Out:
# 27

# %% [markdown]
# ### Raiz

# %%
4**(1/2) # raiz quadrada de 4
# Out:
# 2.0

# %% [markdown]
# ## Resto da divisão

# %%
4 % 2 # mod - 4 mod 2
# Out:
# 0

# %%
5 % 3 # 5 mod 3
# Out:
# 2

# %%
64 % 4
# Out:
# 0

# %% [markdown]
# ## Exemplos

# %% [markdown]
# ### Cálculo do IMC
#
# Peso: 55kg
# Altura: 1.65

# %%
55 / (1.65 * 1.65)
# Out:
# 20.202020202020204

# %%
55 / 1.65 * 1.65
# Out:
# 55.0

# %% [markdown]
# ## Pontos de atenção!
#
#
#
# *   Quando estiver fazendo código ter atenção com a ordem das operações, quando quiser que uma operação seja feita primeiro use os `()`
# *   Quando queremos escrever números decimais usamos o `.`, por exemplo o 1.65
